# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()


print("LETTUCE")

density1=np.array([180,480,1920,7680])



inv_a2=np.array([0.0098,0.0468,0.1032,0.2789])
a2=list(1/inv_a2)
inv_a3=np.array([0.0044,0.0331,0.0684,0.1829])
a3=list(1/inv_a3)
inv_a4=np.array([0.0034,0.0142,0.1891,1.1398])
a4=list(1/inv_a4)



Y2=np.log(inv_a2)
Y3=np.log(inv_a3)
Y4=np.log(inv_a4)


T2=np.array([13,19,22,27])
T3=np.array([19,34,42,50])
T4=np.array([16,23,35,43])






Y2L=list(np.log(inv_a2))
Y3L=list(np.log(inv_a3))
Y4L=list(np.log(inv_a4))
Y=Y2L+Y3L+Y4L



def calcul_a_and_b(Y,X) :
    Ymoy=np.mean(Y)
    Xmoy=np.mean(X)
    num=0   # Numérateur
    den=0   # Dénominateur
    for i in range(len(X)):
        num=num+((X[i]-Xmoy)*(Y[i]-Ymoy))
        den=den+(X[i]-Xmoy)**2
    a=num/den
    b=Ymoy-a*Xmoy
    return b,a



[z2,k2]=calcul_a_and_b(Y2,T2)
[z3,k3]=calcul_a_and_b(Y3,T3)
[z4,k4]=calcul_a_and_b(Y4,T4)


Y2P=z2+k2*T2
Y3P=z3+k3*T3
Y4P=z4+k4*T4

titre=[
      '3/09/1981',
       '14/10/1981',
      '16/03/1982']



plt.scatter(T2,Y2,label='03/09/81')
plt.plot(T2,Y2P)
plt.scatter(T3,Y3,label='14/10/81')
plt.plot(T3,Y3P)
plt.scatter(T4,Y4,label='16/03/82')
plt.plot(T4,Y4P)
plt.xlabel("TIME")
plt.ylabel("ln(a^(-1))")
#plt.title('(A)')
#plt.subplots_adjust(left=0.18, bottom=0.11, right=0.99, top=0.98, wspace=0.246)
plt.legend()
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# LETTUCE

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()

print("LETTUCE")

density1=np.array([180,480,1920,7680])



inv_a2=np.array([0.0098,0.0468,0.1032,0.2789])
a2=list(1/inv_a2)
inv_a3=np.array([0.0044,0.0331,0.0684,0.1829])
a3=list(1/inv_a3)
inv_a4=np.array([0.0034,0.0142,0.1891,1.1398])
a4=list(1/inv_a4)



Y2=np.log(inv_a2)
Y3=np.log(inv_a3)
Y4=np.log(inv_a4)


T2=np.array([200,290,335,390])
T3=np.array([180,340,405,455])
T4=np.array([135,205,315,420])







Y2L=list(np.log(inv_a2))
Y3L=list(np.log(inv_a3))
Y4L=list(np.log(inv_a4))
Y=Y2L+Y3L+Y4L



def calcul_a_and_b(Y,X) :
    Ymoy=np.mean(Y)
    Xmoy=np.mean(X)
    num=0   # Numérateur
    den=0   # Dénominateur
    for i in range(len(X)):
        num=num+((X[i]-Xmoy)*(Y[i]-Ymoy))
        den=den+(X[i]-Xmoy)**2
    a=num/den
    b=Ymoy-a*Xmoy
    return b,a



[z2,k2]=calcul_a_and_b(Y2,T2)
[z3,k3]=calcul_a_and_b(Y3,T3)
[z4,k4]=calcul_a_and_b(Y4,T4)


Y2P=z2+k2*T2
Y3P=z3+k3*T3
Y4P=z4+k4*T4

titre=[
      '3/09/1981',
       '14/10/1981',
      '16/03/1982']




plt.scatter(T2,Y2,label='03/09/81')
plt.plot(T2,Y2P)
plt.scatter(T3,Y3,label='14/10/81')
plt.plot(T3,Y3P)
plt.scatter(T4,Y4,label='16/03/82')
plt.plot(T4,Y4P)
#plt.title('(B)')
plt.xlabel("DD")
plt.ylabel("ln(a^(-1))")
#plt.subplots_adjust(left=0.18, bottom=0.11, right=0.99, top=0.98, wspace=0.246)
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# LETTUCE

# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()

DD=np.array([ 200,290,335,390,180,340,405,455,135,205,315,420])
R=np.array([54, 68.5125, 76.16842105, 95.27142857,
            32.4, 43.71428571, 50.38676471, 59.76486486,
            53.46, 65.6, 150.255, 189])
t=np.linspace(50,350,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']

def Shinozaki_Kira(DD, R, log_w0, k, f):
    EDD  = 1 / ( (1/DD)+f*(1/R) )
    return log_w0+k*EDD



inv_a2=np.array([0.0098,0.0468,0.1032,0.2789])
inv_a3=np.array([0.0044,0.0331,0.0684,0.1829])
inv_a4=np.array([0.0034,0.0142,0.1891,1.1398])
inv_a=np.concatenate((inv_a2,inv_a3,inv_a4))
Y=np.log(inv_a)

def objective(params):
    log_w0, k, f = params
    y_pred = np.array([Shinozaki_Kira(DD[i], R[i], log_w0, k, f) for i in range(len(DD))])
    y_obs = Y
    return sum((y_obs - y_pred) ** 2)


params0 = [-7, 1, 0.9]
result = minimize(objective, params0)
print("Paramètres optimaux : log_w0= %.8f, k = %.8f, f=%.8f" % tuple(result.x))

y_obs = Y

# Calcul de la somme des carrés totale
y_mean = np.mean(y_obs)
SST = sum((y_obs - y_mean) ** 2)

# Calcul de la somme des carrés résiduels
log_w0_opt, k_opt, f_opt = result.x
y_pred = np.array([Shinozaki_Kira(DD[i], R[i], log_w0_opt, k_opt, f_opt) for i in range(len(DD))])
SSR = sum((y_obs - y_pred) ** 2)

# Calcul du coefficient de détermination
R2 = 1 - (SSR / SST)
print("Coefficient de détermination : R2 = %.4f" % R2)
EDD=1/ ((1/DD)+f_opt*(1/R))
#plt.scatter(EDD, y_obs,label='observed data')
#plt.xlabel('EDD')
plt.title('Relationship between ln(1/a) and EDD')


def Shinozaki_Kira2(EDD, log_w0, k, f):
    return log_w0+k*EDD
#plt.plot(t,Shinozaki_Kira2(t, log_w0_opt, k_opt, f_opt),color='red',label='fitted data')


import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
DD=np.array([[200,290,335,390],[180,340,405,455],[135,205,315,420]])
R=np.array([
            [54, 68.5125, 76.16842105, 95.27142857],
            [32.4, 43.71428571, 50.38676471, 59.76486486],
            [53.46, 65.6, 150.255, 189]])

inv_a2=np.array([0.0098,0.0468,0.1032,0.2789])
inv_a3=np.array([0.0044,0.0331,0.0684,0.1829])
inv_a4=np.array([0.0034,0.0142,0.1891,1.1398])
inv_a=np.array([inv_a2,inv_a3,inv_a4])
Y=np.log(inv_a)
t=np.linspace(50,350,1000)
date=['03/09/81','14/10/81','16/03/82']
EDD=1/ ( (1/DD)+f_opt*(1/R))


for i in range(0,3):
    plt.scatter(EDD[i],Y[i],label=date[i])


def Shinozaki_Kira2(EDD, log_w0, k, f):
    return log_w0+k*EDD
plt.plot(t,Shinozaki_Kira2(t, log_w0_opt, k_opt, f_opt),label='fitted data')
plt.xlabel('EDD')
plt.ylabel("ln(a^(-1))")
#plt.title('(C)')
#plt.subplots_adjust(left=0.18, bottom=0.11, right=0.99, top=0.98, wspace=0.246)
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Paramètres optimaux : log_w0= -8.27094231, k = 0.02466164, f=0.09340115
# Coefficient de détermination : R2 = 0.9967
# Using matplotlib backend: TkAgg
