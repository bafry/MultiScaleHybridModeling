# %% [markdown]
# # Description

# %%
#     Gompertz model
#  mean plant weight as a function of Effective-day-degrees (EDD) for different densities d=180, d= 480, d=1920, d=7680
#  
#    
#

# %% [markdown]
# # d = 180

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()

DD=np.array([200, 290, 335, 390, 180, 340, 405, 455, 135, 205, 315, 420 ])
R=np.array([ 54, 68.5125, 76.16842105, 95.27142857,
            32.4, 43.71428571, 50.38676471, 59.76486486,
            53.46, 65.6, 150.255, 189])
time=np.array([13,19,22,27,19,34,42,50,16,23,35,43])
intervale=np.linspace(80,350,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']


def gompertz(DD, R, a, b, f, c, n):
    EDD  = 1 / ( (1/DD)+f*(1/R) )
    return a * np.exp(-b * np.exp(-c * EDD))

weights=np.array(  [
                    0.009687573, 0.044685234, 0.094008898, 0.227650969,
                    0.004384217, 0.031238793, 0.061785221, 0.146166469,
                    0.003410082, 0.014033932, 0.166518499, 0.791899893])



def objective(params):
    a, b, f, c= params
    y_pred = np.array([gompertz(DD[i], R[i], a, b, f, c, time[i]) for i in range(len(DD))])
    y_obs = weights
    return sum((y_obs - y_pred) ** 2)

params0 = [1, 10, 0.009, 0.001]
result = minimize(objective, params0)
print("Paramètres optimaux : a = %.8f, b = %.8f, f=%.8f, c = %.8f, " % tuple(result.x))

y_obs = weights

# Calcul de la somme des carrés totale
y_mean = np.mean(y_obs)
SST = sum((y_obs - y_mean) ** 2)

# Calcul de la somme des carrés résiduels
a_opt, b_opt, f_opt, c_opt = result.x
y_pred = np.array([gompertz(DD[i], R[i], a_opt, b_opt, f_opt, c_opt, time[i]) for i in range(len(DD))])
SSR = sum((y_obs - y_pred) ** 2)

# Calcul du coefficient de détermination
R2 = 1 - (SSR / SST)
plt.xlabel('EDD')
plt.ylabel('mean dry weight per plant')
print("Coefficient de détermination : R2 = %.4f" % R2)
print("Coefficient de détermination : SSR = %.8f" % SSR)
EDD=1/ ((1/DD)+f_opt*(1/R))


DD=np.array([[200, 290, 335, 390],[ 180, 340, 405, 455],[ 135, 205, 315, 420 ]])
R=np.array([
            [54, 68.5125, 76.16842105, 95.27142857],
            [32.4, 43.71428571, 50.38676471, 59.76486486],
            [53.46, 65.6, 150.255, 189]])
time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])
intervale=np.linspace(90,350,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']



weights=np.array([  
                    [0.009687573, 0.044685234, 0.094008898, 0.227650969],
                    [0.004384217, 0.031238793, 0.061785221, 0.146166469],
                    [0.003410082, 0.014033932, 0.166518499, 0.791899893]])


EDD=1/ ((1/DD)+f_opt*(1/R))
plt.plot()
for i in range(0,3):
    plt.scatter(EDD[i],weights[i],label=date[i])

def gompertz2(EDD, a, b, c):
    return a * np.exp(-b * np.exp(-c * EDD))
plt.plot(intervale,gompertz2(intervale, a_opt, b_opt, c_opt),label='fitted data')
plt.title('density=180 (R2=%.4f)'%R2)
plt.ylabel('mean plant weoght (g/plant)')
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Paramètres optimaux : a = 167.08584455, b = 15.24267172, f=0.10756124, c = 0.00308760,
# Coefficient de détermination : R2 = 0.9998
# Coefficient de détermination : SSR = 0.00010691

# %% [markdown]
# # d = 480

# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()

DD=np.array([200, 290, 335, 390, 180, 340, 405, 455, 135, 205, 315, 420 ])
R=np.array([ 54, 68.5125, 76.16842105, 95.27142857,
            32.4, 43.71428571, 50.38676471, 59.76486486,
            53.46, 65.6, 150.255, 189])
time=np.array([13,19,22,27,19,34,42,50,16,23,35,43])
intervale=np.linspace(80,350,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']

def gompertz(DD, R, a, b, f, c, n): 
    EDD  = 1 / ( (1/DD)+f*(1/R) )
    return a * np.exp(-b * np.exp(-c * EDD))



weights=np.array([  
                    0.00950582, 0.041555591, 0.081858259, 0.174277332,
                    0.004358162, 0.02856206, 0.053209048, 0.109509946,
                    0.003427019, 0.013765618, 0.138878128, 0.524883641])



def objective(params):
    a, b, f, c = params
    y_pred = np.array([gompertz(DD[i], R[i], a, b, f, c, time[i]) for i in range(len(DD))])
    y_obs = weights
    return sum((y_obs - y_pred) ** 2)


params0 = [1, 10, 0.009, 0.001]
#params0 = [100, 19, 0.09, 0.001]
result = minimize(objective, params0)
print("Paramètres optimaux : a = %.8f, b = %.8f, f=%.8f, c = %.8f" % tuple(result.x))
y_obs = weights

# Calcul de la somme des carrés totale
y_mean = np.mean(y_obs)
SST = sum((y_obs - y_mean) ** 2)

# Calcul de la somme des carrés résiduels
a_opt, b_opt, f_opt, c_opt = result.x
y_pred = np.array([gompertz(DD[i], R[i], a_opt, b_opt, f_opt, c_opt, time[i]) for i in range(len(DD))])
SSR = sum((y_obs - y_pred) ** 2)

# Calcul du coefficient de détermination
R2 = 1 - (SSR / SST)
plt.xlabel('EDD')
print("Coefficient de détermination : R2 = %.4f" % R2)
print("Coefficient de détermination : SSR = %.8f" % SSR)
EDD=1/ ((1/DD)+f_opt*(1/R))

DD=np.array([[200, 290, 335, 390],[ 180, 340, 405, 455],[ 135, 205, 315, 420 ]])
R=np.array([
            [54, 68.5125, 76.16842105, 95.27142857],
            [32.4, 43.71428571, 50.38676471, 59.76486486],
            [53.46, 65.6, 150.255, 189]])
time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])
intervale=np.linspace(90,350,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']
weights=np.array([  
                    [0.00950582, 0.041555591, 0.081858259, 0.174277332],
                    [0.004358162, 0.02856206, 0.053209048, 0.109509946],
                    [0.003427019, 0.013765618, 0.138878128, 0.524883641]])
EDD=1/ ((1/DD)+f_opt*(1/R))
plt.plot()
for i in range(0,3):
    plt.scatter(EDD[i],weights[i],label=date[i])
plt.plot(intervale,gompertz2(intervale, a_opt, b_opt, c_opt),label='fitted data')
plt.title('density=480 (R2=%.4f)'%R2)
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Paramètres optimaux : a = 26.31353823, b = 12.93764967, f=0.11775442, c = 0.00359084
# Coefficient de détermination : R2 = 0.9997
# Coefficient de détermination : SSR = 0.00007802

# %% [markdown]
# # d = 1920

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()

DD=np.array([200, 290, 335, 390, 180, 340, 405, 455, 135, 205, 315, 420 ])
R=np.array([ 54, 68.5125, 76.16842105, 95.27142857,
            32.4, 43.71428571, 50.38676471, 59.76486486,
            53.46, 65.6, 150.255, 189])
time=np.array([13,19,22,27,19,34,42,50,16,23,35,43])
intervale=np.linspace(80,350,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']


def gompertz(DD, R, a, b, f, c, n):
    EDD  = 1 / ( (1/DD)+f*(1/R) )
    return a * np.exp(-b * np.exp(-c * EDD))

weights=np.array(  [
                    0.008720495, 0.031100293, 0.050517334, 0.081998265,
                    0.004237288, 0.020238212, 0.031933032, 0.049692016,
                    0.003510715, 0.012608524, 0.077294031, 0.200453187])


def objective(params):
    a, b, f, c = params
    y_pred = np.array([gompertz(DD[i], R[i], a, b, f, c, time[i]) for i in range(len(DD))])
    y_obs = weights
    return sum((y_obs - y_pred) ** 2)

params0 = [30, 10, 0.05, 0.001]
#params0 = [50, 19, 0.09, 0.001]
result = minimize(objective, params0)
print("Paramètres optimaux : a = %.8f, b = %.8f, f=%.8f, c = %.8f" % tuple(result.x))

y_obs = weights

# Calcul de la somme des carrés totale
y_mean = np.mean(y_obs)
SST = sum((y_obs - y_mean) ** 2)

# Calcul de la somme des carrés résiduels
a_opt, b_opt, f_opt, c_opt = result.x
y_pred = np.array([gompertz(DD[i], R[i], a_opt, b_opt, f_opt, c_opt, time[i]) for i in range(len(DD))])
SSR = sum((y_obs - y_pred) ** 2)

# Calcul du coefficient de détermination
R2 = 1 - (SSR / SST)
plt.xlabel('EDD')
print("Coefficient de détermination : R2 = %.4f" % R2)
print("Coefficient de détermination : SSR = %.8f" % SSR)
EDD=1/ ((1/DD)+f_opt*(1/R))

DD=np.array([[200, 290, 335, 390],[ 180, 340, 405, 455],[ 135, 205, 315, 420 ]])
R=np.array([
            [54, 68.5125, 76.16842105, 95.27142857],
            [32.4, 43.71428571, 50.38676471, 59.76486486],
            [53.46, 65.6, 150.255, 189]])
time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])
intervale=np.linspace(90,350,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']


weights=np.array([  
                    [0.008720495, 0.031100293, 0.050517334, 0.081998265],
                    [0.004237288, 0.020238212, 0.031933032, 0.049692016],
                    [0.003510715, 0.012608524, 0.077294031, 0.200453187]])


 
EDD=1/ ((1/DD)+f_opt*(1/R))
for i in range(0,3):
    plt.scatter(EDD[i],weights[i],label=date[i])

def gompertz2(EDD, a, b, c):
    return a * np.exp(-b * np.exp(-c * EDD))
plt.plot(intervale,gompertz2(intervale, a_opt, b_opt, c_opt),label='fitted data')
plt.title('density=1920 (R2=%.4f)'%R2)
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Paramètres optimaux : a = 2.51345940, b = 9.27436980, f=0.15006972, c = 0.00412407
# Coefficient de détermination : R2 = 0.9980
# Coefficient de détermination : SSR = 0.00006564

# %% [markdown]
# # d = 7680

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()

DD=np.array([200, 290, 335, 390, 180, 340, 405, 455, 135, 205, 315, 420 ])
R=np.array([ 54, 68.5125, 76.16842105, 95.27142857,
            32.4, 43.71428571, 50.38676471, 59.76486486,
            53.46, 65.6, 150.255, 189])
time=np.array([13,19,22,27,19,34,42,50,16,23,35,43])
intervale=np.linspace(50,350,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']


def gompertz(DD, R, a, b, f, c, n): 
    EDD  = 1 / ( (1/DD)+f*(1/R) )
    return a * np.exp(-b * np.exp(-c * EDD))

weights=np.array([  
                    0.006554492, 0.01550061, 0.019955708, 0.026298504,
                    0.003814147, 0.009344792, 0.012284636, 0.015602225,
                    0.003890805, 0.009435913, 0.027866162, 0.057727578])



def objective(params):
    a, b, f, c = params
    y_pred = np.array([gompertz(DD[i], R[i], a, b, f, c, time[i]) for i in range(len(DD))])
    y_obs = weights
    return sum((y_obs - y_pred) ** 2)

params0 = [0.5, 10, 0.09, 0.002]
#params0 = [1, 19, 0.09, 0.001]
result = minimize(objective, params0)
print("Paramètres optimaux : a = %.8f, b = %.8f, f=%.8f, c = %.8f" % tuple(result.x))

y_obs = weights

# Calcul de la somme des carrés totale
y_mean = np.mean(y_obs)
SST = sum((y_obs - y_mean) ** 2)

# Calcul de la somme des carrés résiduels
a_opt, b_opt, f_opt, c_opt = result.x
y_pred = np.array([gompertz(DD[i], R[i], a_opt, b_opt, f_opt, c_opt, time[i]) for i in range(len(DD))])
SSR = sum((y_obs - y_pred) ** 2)

# Calcul du coefficient de détermination
R2 = 1 - (SSR / SST)
plt.xlabel('EDD')
print("Coefficient de détermination : R2 = %.4f" % R2)
print("Coefficient de détermination : SSR = %.8f" % SSR)
EDD=1/ ((1/DD)+f_opt*(1/R))

import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt



DD=np.array([[200, 290, 335, 390],[ 180, 340, 405, 455],[ 135, 205, 315, 420 ]])
R=np.array([
            [54, 68.5125, 76.16842105, 95.27142857],
            [32.4, 43.71428571, 50.38676471, 59.76486486],
            [53.46, 65.6, 150.255, 189]])
time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])
intervale=np.linspace(70,350,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']
weights=np.array([  
                    [0.006554492, 0.01550061, 0.019955708, 0.026298504],
                    [0.003814147, 0.009344792, 0.012284636, 0.015602225],
                    [0.003890805, 0.009435913, 0.027866162, 0.057727578]])


EDD=1/ ((1/DD)+f_opt*(1/R))
plt.xlabel('EDD')
for i in range(0,3):
    plt.scatter(EDD[i],weights[i],label=date[i])

def gompertz2(EDD, a, b, c):
    return a * np.exp(-b * np.exp(-c * EDD))
plt.xlabel('EDD')
plt.plot(intervale,gompertz2(intervale, a_opt, b_opt, c_opt),label='fitted data')
plt.title('density=7680 (R2=%.4f)'%R2)
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Paramètres optimaux : a = 1.04017079, b = 7.00996029, f=0.21145675, c = 0.00309337
# Coefficient de détermination : R2 = 0.9914
# Coefficient de détermination : SSR = 0.00002117
