# %% [markdown]
# # Logistic

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()



w0 = np.array([0.00034439, 0.00050975, 0.00098824, 0.00149905])
k = np.array([1.87564838, 1.09293809, 0.37608501, 0.13670977])
f = np.array([0.10687613, 0.11651107, 0.14602330, 0.20416074])
r = np.array([0.02442168, 0.02275224, 0.01913844, 0.01447848])




density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']
def logistic1(sum_temperature, R, w0, k, f, n, r):
    DD = sum_temperature 
    EDD  = 1 / ( (1/DD)+f*(1/R) )
    return k / (1 + ((k / w0)-1) * np.exp(-r * EDD))





sum_temperature=np.array([[200, 290, 335, 390],[ 180, 340, 405, 455],[ 135, 205, 315, 420 ]])
R=np.array([
            [54, 68.5125, 76.16842105, 95.27142857],
            [32.4, 43.71428571, 50.38676471, 59.76486486],
            [53.46, 65.6, 150.255, 189]])
time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])






weights=np.array([  
                    [0.009687573, 0.044685234, 0.094008898, 0.227650969],
                    [0.004384217, 0.031238793, 0.061785221, 0.146166469],
                    [0.003410082, 0.014033932, 0.166518499, 0.791899893]])


plt.subplot(141)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.125, bottom=0.11, right=0.98, top=0.943, wspace=0.246)
plt.title('density = 180')
plt.ylabel('Observed Dry weight DW')
plt.xlabel('Estimated DW')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(logistic1(sum_temperature[j], R[j], w0[0], k[0], f[0], density[0], r[0]), weights[j])

    
    
    
    
    
    
weights=np.array([  
                    [0.00950582, 0.041555591, 0.081858259, 0.174277332],
                    [0.004358162, 0.02856206, 0.053209048, 0.109509946],
                    [0.003427019, 0.013765618, 0.138878128, 0.524883641]])
plt.subplot(142)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.125, bottom=0.11, right=0.98, top=0.943, wspace=0.246)
plt.title('density = 480')
plt.xlabel('Estimated DW')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(logistic1(sum_temperature[j], R[j], w0[1], k[1], f[1], density[1], r[1]), weights[j])

    
    
    
    
    
    
    
    
weights=np.array([  
                    [0.008720495, 0.031100293, 0.050517334, 0.081998265],
                    [0.004237288, 0.020238212, 0.031933032, 0.049692016],
                    [0.003510715, 0.012608524, 0.077294031, 0.200453187]])

plt.subplot(143)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.125, bottom=0.11, right=0.98, top=0.943, wspace=0.246)
plt.title('density = 1920')
plt.xlabel('Estimated DW')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(logistic1(sum_temperature[j], R[j], w0[2], k[2], f[2], density[2], r[2]), weights[j])
    
    
    
    
    
weights=np.array([  
                    [0.006554492, 0.01550061, 0.019955708, 0.026298504],
                    [0.003814147, 0.009344792, 0.012284636, 0.015602225],
                    [0.003890805, 0.009435913, 0.027866162, 0.057727578]])

plt.subplot(144)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.125, bottom=0.11, right=0.98, top=0.943, wspace=0.246)
plt.title('density = 7680')
plt.xlabel('Estimated DW')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(logistic1(sum_temperature[j], R[j], w0[3], k[3], f[3], density[3], r[3]), weights[j])
plt.show()
# Out:
# Using matplotlib backend: TkAgg

# %% [markdown]
# # Gompertz

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()


a = np.array([167.08584455, 26.31353823, 2.51345940, 1.04017079])
b = np.array([15.24267172, 12.93764967, 9.27436980, 7.00996029])
f = np.array([0.10756124, 0.11775442, 0.15006972, 0.21145675])
c = np.array([0.00308760, 0.00359084, 0.00412407, 0.00309337])




density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']



def Gompertz(sum_temperature, R, a, b, f, c):
    DD = sum_temperature
    EDD  = 1 / ( (1/DD)+f*(1/R) )
    return a * np.exp(-b * np.exp(-c * EDD))



sum_temperature=np.array([[200, 290, 335, 390],[ 180, 340, 405, 455],[ 135, 205, 315, 420 ]])
R=np.array([
            [54, 68.5125, 76.16842105, 95.27142857],
            [32.4, 43.71428571, 50.38676471, 59.76486486],
            [53.46, 65.6, 150.255, 189]])
time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])






weights=np.array([  
                    [0.009687573, 0.044685234, 0.094008898, 0.227650969],
                    [0.004384217, 0.031238793, 0.061785221, 0.146166469],
                    [0.003410082, 0.014033932, 0.166518499, 0.791899893]])
plt.subplot(141)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.title('density = 180')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.ylabel('Observed dry weights DW')
plt.xlabel('Estimated DW')
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(Gompertz(sum_temperature[j], R[j], a[0], b[0], f[0], c[0]), weights[j])

    
    
    
    
    
    
weights=np.array([  
                    [0.00950582, 0.041555591, 0.081858259, 0.174277332],
                    [0.004358162, 0.02856206, 0.053209048, 0.109509946],
                    [0.003427019, 0.013765618, 0.138878128, 0.524883641]])
plt.subplot(142)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.title('density = 480')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.xlabel('Estimated DW')
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(Gompertz(sum_temperature[j], R[j], a[1], b[1], f[1], c[1]), weights[j])

    
    
    
    
    
    
    
    
weights=np.array([  
                    [0.008720495, 0.031100293, 0.050517334, 0.081998265],
                    [0.004237288, 0.020238212, 0.031933032, 0.049692016],
                    [0.003510715, 0.012608524, 0.077294031, 0.200453187]])
plt.subplot(143)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.title('density = 1920')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.xlabel('Estimated DW')
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(Gompertz(sum_temperature[j], R[j], a[2], b[2], f[2], c[2]), weights[j])
    
    
    
    
    
weights=np.array([  
                    [0.006554492, 0.01550061, 0.019955708, 0.026298504],
                    [0.003814147, 0.009344792, 0.012284636, 0.015602225],
                    [0.003890805, 0.009435913, 0.027866162, 0.057727578]])
plt.subplot(144)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.title('density = 7680')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.xlabel('Estimated DW')
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(Gompertz(sum_temperature[j], R[j], a[3], b[3], f[3], c[3]), weights[j])
plt.show()
# Out:
# Using matplotlib backend: TkAgg

# %% [markdown]
# # Aikman and Scaife

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()



    
    
    
f0 = np.array([0.00045155, 0.00118687, 0.00718936, 0.03093226])
f = np.array([0.10698924, 0.11668077, 0.14734754, 0.20678644])
KF = np.array([0.00781957, 0.00542550, 0.00449016, 0.00295530])
r = np.array([ 0.02481226, 0.02340976, 0.02040752, 0.01540276])




density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']



def Aikman(sum_temperature, R, f0, f, KF, r, n):
    DD = sum_temperature 
    EDD = 1 / ( (1/DD)+f*(1/R) )
    return np.log( 1 + ((f0/(1-f0)) * np.exp(r*EDD)) ) / ( n * KF)





sum_temperature=np.array([[200, 290, 335, 390],[ 180, 340, 405, 455],[ 135, 205, 315, 420 ]])
R=np.array([
            [54, 68.5125, 76.16842105, 95.27142857],
            [32.4, 43.71428571, 50.38676471, 59.76486486],
            [53.46, 65.6, 150.255, 189]])
time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])






weights=np.array([  
                    [0.009687573, 0.044685234, 0.094008898, 0.227650969],
                    [0.004384217, 0.031238793, 0.061785221, 0.146166469],
                    [0.003410082, 0.014033932, 0.166518499, 0.791899893]])
plt.subplot(141)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ticklabel_format(axis='X', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.title('density = 180')
plt.xlabel('Estimated DW')
plt.ylabel('Observed dry weight DW ')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(Aikman(sum_temperature[j], R[j], f0[0], f[0], KF[0], r[0], density[0]), weights[j])

    
    
    
    
    
    
weights=np.array([  
                    [0.00950582, 0.041555591, 0.081858259, 0.174277332],
                    [0.004358162, 0.02856206, 0.053209048, 0.109509946],
                    [0.003427019, 0.013765618, 0.138878128, 0.524883641]])
plt.subplot(142)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ticklabel_format(axis='X', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.title('density = 480')
plt.xlabel('Estimated DW')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(Aikman(sum_temperature[j], R[j], f0[1], f[1], KF[1], r[1], density[1]), weights[j])

    
    
    
    
    
    
    
    
weights=np.array([  
                    [0.008720495, 0.031100293, 0.050517334, 0.081998265],
                    [0.004237288, 0.020238212, 0.031933032, 0.049692016],
                    [0.003510715, 0.012608524, 0.077294031, 0.200453187]])
plt.subplot(143)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ticklabel_format(axis='X', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.title('density = 1920')
plt.xlabel('Estimated DW')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(Aikman(sum_temperature[j], R[j], f0[2], f[2], KF[2], r[2], density[2]), weights[j])
    
    
    
    
    
weights=np.array([  
                    [0.006554492, 0.01550061, 0.019955708, 0.026298504],
                    [0.003814147, 0.009344792, 0.012284636, 0.015602225],
                    [0.003890805, 0.009435913, 0.027866162, 0.057727578]])
plt.subplot(144)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ticklabel_format(axis='X', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.title('density = 7680')
plt.xlabel('Estimated DW')
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
for j in range(0,3):
    plt.scatter(Aikman(sum_temperature[j], R[j], f0[3], f[3], KF[3], r[3], density[3]), weights[j])
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.show()
plt.pause(0.06)
# Out:
# Using matplotlib backend: TkAgg

# %% [markdown]
# # Scaife, Cox and Morris

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()


w0=0.0002558
p=0.02466
f=0.0934
inv_q=0.00925745
density=np.array([180,480,1920,7680])

MDR2=np.array([4.242, 3.646, 3.646, 3.377])
MDR3=np.array([1.96, 1.077, 0.86, 0.86])
MDR4=np.array([4.242, 4.242, 4.807, 6.3])
MDR=np.array([[4.242, 3.646, 3.646, 3.377], [1.96, 1.077, 0.86, 0.86], [4.242, 4.242, 4.807, 6.3]])





DD=np.array([[200, 290, 335, 390],[ 180, 340, 405, 455],[ 135, 205, 315, 420 ]])
R=np.array([
            [54, 68.5125, 76.16842105, 95.27142857],
            [32.4, 43.71428571, 50.38676471, 59.76486486],
            [53.46, 65.6, 150.255, 189]])



EDD=1/( (1/DD) + f * (1/R) )







def w_estimated(DD, R, density, MDR) : 
    EDD = 1/((1/DD) + f*(1/R))
    return  1/ ( (1/w0)*np.exp(-p*EDD) + density * inv_q *(1/ MDR))






weights=np.array([  
                    [0.009687573, 0.044685234, 0.094008898, 0.227650969],
                    [0.004384217, 0.031238793, 0.061785221, 0.146166469],
                    [0.014033932, 0.014033932, 0.166518499, 0.791899893]])


plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ticklabel_format(axis='X', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
for i in range(3):
    plt.subplot(141)
    plt.xlabel('Estimated DW')
    plt.ylabel('Observed dry weight DW')
    plt.title('density = 180')
    plt.scatter(w_estimated(DD[i], R[i], 180, MDR[i]), weights[i])
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
    
    
weights=np.array([  
                    [0.00950582, 0.041555591, 0.081858259, 0.174277332],
                    [0.004358162, 0.02856206, 0.053209048, 0.109509946],
                    [0.013765618, 0.013765618, 0.138878128, 0.524883641]])

plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ticklabel_format(axis='X', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
for i in range(3):
    plt.subplot(142)
    plt.xlabel('Estimated DW')
    plt.title('density = 480')
    plt.scatter(w_estimated(DD[i], R[i], 480, MDR[i]), weights[i])
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
    
    

weights=np.array([  
                    [0.008720495, 0.031100293, 0.050517334, 0.081998265],
                    [0.004237288, 0.020238212, 0.031933032, 0.049692016],
                    [0.012608524, 0.012608524, 0.077294031, 0.200453187]])

plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ticklabel_format(axis='X', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
for i in range(3):
    plt.subplot(143)
    plt.title('density = 1920')
    plt.xlabel('Estimated DW')
    plt.scatter(w_estimated(DD[i], R[i], 1920, MDR[i]), weights[i])
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
    
    
    
weights=np.array([  
                    [0.006554492, 0.01550061, 0.019955708, 0.026298504],
                    [0.003814147, 0.009344792, 0.012284636, 0.015602225],
                    [0.009435913, 0.009435913, 0.027866162, 0.057727578]])

plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ticklabel_format(axis='X', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
for i in range(3):
    plt.subplot(144)
    plt.title('density = 7680')
    plt.xlabel('Estimated DW')
    plt.scatter(w_estimated(DD[i], R[i], 7680, MDR[i]), weights[i])
maxx=np.max(weights)
intervale=np.linspace(0, maxx, 1000)
plt.plot(intervale, intervale)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
plt.ticklabel_format(axis='X', style='sci', scilimits=(0,0))
plt.subplots_adjust(left=0.047, bottom=0.108, right=0.988, top=0.94, wspace=0.246)
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# C:\Users\0\AppData\Local\Temp\ipykernel_276\778429565.py:60: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
