# %% [markdown]
# # Description

# %%
#     Aikmane & Scaife model
#  mean plant weight as a function of time (t) for different densities d=180, d= 480, d=1920, d=7680
#  
#    
#
#
#
#   In conclusion, I have plot the four denisties in one figure using subplot
#

# %% [markdown]
# # d = 180

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()



time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])
t=np.linspace(0,55,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']

def Aikman_1(t, f0, KF, r):
    return np.log( 1 + ((f0/(1-f0)) * np.exp(r*t)) ) / ( density[0] *KF)

weights=np.array([  
                    [0.009687573, 0.044685234, 0.094008898, 0.227650969],
                    [0.004384217, 0.031238793, 0.061785221, 0.146166469],
                    [0.003410082, 0.014033932, 0.166518499, 0.791899893]])

for i in range(0,3):
    
    def objective(params):
        f0, KF, r = params
        y_pred = np.array([Aikman_1(time[i][j], f0, KF, r) for j in range(len(time[0]))]) 
        y_obs = weights[i]
        return sum((y_obs - y_pred) ** 2)


    params0 = [0.05, 0.01, 0.002]
    result = minimize(objective, params0)
    print("Paramètres optimaux : f0 = %.8f, KF = %.8f, r = %.8f" % tuple(result.x))

    y_obs = weights[i]

    # Calcul de la somme des carrés totale
    y_mean = np.mean(y_obs)
    SST = sum((y_obs - y_mean) ** 2)

    # Calcul de la somme des carrés résiduels
    f0_opt, KF_opt, r_opt = result.x
    y_pred = np.array([Aikman_1(time[i][j], f0_opt, KF_opt, r_opt) for j in range(len(time[0]))])
    SSR = sum((y_obs - y_pred) ** 2)

    # Calcul du coefficient de détermination
    R2 = 1 - (SSR / SST)
    print("Coefficient de détermination : R2 = %.4f" % R2)
    plt.plot(t, Aikman_1(t,f0_opt, KF_opt, r_opt),ls="-",label=('date=%s'%date[i]),lw=1)
    plt.scatter(time[i], y_obs)
    plt.xlabel('days from sowing')
    plt.ylabel('mean plant weight')
    plt.title('density=180')
    plt.legend()
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Paramètres optimaux : f0 = 0.00129229, KF = 0.04397697, r = 0.30638906
# Coefficient de détermination : R2 = 0.9999
# Paramètres optimaux : f0 = 0.00018786, KF = 0.00124424, r = 0.10350691
# Coefficient de détermination : R2 = 0.9984
# Paramètres optimaux : f0 = 0.00000021, KF = 0.02958819, r = 0.45235471
# Coefficient de détermination : R2 = 0.9976

# %% [markdown]
# # d = 480

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()



time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])
t=np.linspace(0,55,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']

def Aikman_1(t, f0, KF, r):
    return np.log( 1 + ((f0/(1-f0)) * np.exp(r*t)) ) / ( density[1] *KF)

weights=np.array([  
                    [0.00950582, 0.041555591, 0.081858259, 0.174277332],
                    [0.004358162, 0.02856206, 0.053209048, 0.109509946],
                    [0.003427019, 0.013765618, 0.138878128, 0.524883641]])

for i in range(0,3):
    
    def objective(params):
        f0, KF, r = params
        y_pred = np.array([Aikman_1(time[i][j], f0, KF, r) for j in range(len(time[0]))]) 
        y_obs = weights[i]
        return sum((y_obs - y_pred) ** 2)


    params0 = [0.01, 0.001, 0.01]
    result = minimize(objective, params0)
    print("Paramètres optimaux : f0 = %.8f, KF = %.8f, r = %.8f" % tuple(result.x))

    y_obs = weights[i]

    # Calcul de la somme des carrés totale
    y_mean = np.mean(y_obs)
    SST = sum((y_obs - y_mean) ** 2)

    # Calcul de la somme des carrés résiduels
    f0_opt, KF_opt, r_opt = result.x
    y_pred = np.array([Aikman_1(time[i][j], f0_opt, KF_opt, r_opt) for j in range(len(time[0]))])
    SSR = sum((y_obs - y_pred) ** 2)

    # Calcul du coefficient de détermination
    R2 = 1 - (SSR / SST)
    print("Coefficient de détermination : R2 = %.4f" % R2)
    plt.plot(t, Aikman_1(t,f0_opt, KF_opt, r_opt),ls="-",label=('date=%s'%date[i]),lw=1)
    plt.scatter(time[i], y_obs)
    plt.xlabel('days from sowing')
    plt.ylabel('mean plant weight')
    plt.title('density=480')
    plt.legend()
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Paramètres optimaux : f0 = 0.00211784, KF = 0.02753436, r = 0.30944560
# Coefficient de détermination : R2 = 0.9998
# Paramètres optimaux : f0 = 0.00086193, KF = 0.00146751, r = 0.09063112
# Coefficient de détermination : R2 = 0.9981
# Paramètres optimaux : f0 = 0.00017419, KF = 0.00193433, r = 0.19047681
# Coefficient de détermination : R2 = 1.0000

# %% [markdown]
# # d = 1920

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()



time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])
t=np.linspace(0,55,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']

def Aikman_1(t, f0, KF, r):
    return np.log( 1 + ((f0/(1-f0)) * np.exp(r*t)) ) / ( density[2] *KF)

weights=np.array([  
                    [0.008720495, 0.031100293, 0.050517334, 0.081998265],
                    [0.004237288, 0.020238212, 0.031933032, 0.049692016],
                    [0.003510715, 0.012608524, 0.077294031, 0.200453187]])


for i in range(0,3):
    
    def objective(params):
        f0, KF, r = params
        y_pred = np.array([Aikman_1(time[i][j], f0, KF, r) for j in range(len(time[0]))]) 
        y_obs = weights[i]
        return sum((y_obs - y_pred) ** 2)


    params0 = [0.01, 0.001, 0.01]
    result = minimize(objective, params0)
    print("Paramètres optimaux : f0 = %.8f, KF = %.8f, r = %.8f" % tuple(result.x))

    y_obs = weights[i]

    # Calcul de la somme des carrés totale
    y_mean = np.mean(y_obs)
    SST = sum((y_obs - y_mean) ** 2)

    # Calcul de la somme des carrés résiduels
    f0_opt, KF_opt, r_opt = result.x
    y_pred = np.array([Aikman_1(time[i][j], f0_opt, KF_opt, r_opt) for j in range(len(time[0]))])
    SSR = sum((y_obs - y_pred) ** 2)

    # Calcul du coefficient de détermination
    R2 = 1 - (SSR / SST)
    print("Coefficient de détermination : R2 = %.4f" % R2)
    plt.plot(t, Aikman_1(t,f0_opt, KF_opt, r_opt),ls="-",label=('date=%s'%date[i]),lw=1)
    plt.scatter(time[i], y_obs)
    plt.xlabel('days from sowing')
    plt.ylabel('mean plant weight')
    plt.title('density=1920')
    plt.legend()
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Paramètres optimaux : f0 = 0.00647123, KF = 0.02560950, r = 0.33553621
# Coefficient de détermination : R2 = 0.9994
# Paramètres optimaux : f0 = 0.02722422, KF = 0.02668831, r = 0.12045052
# Coefficient de détermination : R2 = 0.9979
# Paramètres optimaux : f0 = 0.00151046, KF = 0.00296289, r = 0.16857956
# Coefficient de détermination : R2 = 1.0000

# %% [markdown]
# # d = 7680

# %%
# %reset -f
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib
plt.ion()
plt.figure()


time=np.array([[13,19,22,27],[19,34,42,50],[16,23,35,43]])
t=np.linspace(0,55,1000)
density=np.array([180,480,1920,7680])
date=['03/09/81','14/10/81','16/03/82']

def Aikman_1(t, f0, KF, r):
    return np.log( 1 + ((f0/(1-f0)) * np.exp(r*t)) ) / ( density[3] *KF)

weights=np.array([  
                    [0.006554492, 0.01550061, 0.019955708, 0.026298504],
                    [0.003814147, 0.009344792, 0.012284636, 0.015602225],
                    [0.003890805, 0.009435913, 0.027866162, 0.057727578]])

for i in range(0,3):
    
    def objective(params):
        f0, KF, r = params
        y_pred = np.array([Aikman_1(time[i][j], f0, KF, r) for j in range(len(time[0]))]) 
        y_obs = weights[i]
        return sum((y_obs - y_pred) ** 2)


    params0 = [0.05, 0.01, 0.002]
    result = minimize(objective, params0)
    print("Paramètres optimaux : f0 = %.8f, KF = %.8f, r = %.8f" % tuple(result.x))

    y_obs = weights[i]

    # Calcul de la somme des carrés totale
    y_mean = np.mean(y_obs)
    SST = sum((y_obs - y_mean) ** 2)

    # Calcul de la somme des carrés résiduels
    f0_opt, KF_opt, r_opt = result.x
    y_pred = np.array([Aikman_1(time[i][j], f0_opt, KF_opt, r_opt) for j in range(len(time[0]))])
    SSR = sum((y_obs - y_pred) ** 2)

    # Calcul du coefficient de détermination
    R2 = 1 - (SSR / SST)
    print("Coefficient de détermination : R2 = %.4f" % R2)
    plt.plot(t, Aikman_1(t,f0_opt, KF_opt, r_opt),ls="-",label=('date=%s'%date[i]),lw=1)
    plt.scatter(time[i], y_obs)
    plt.xlabel('days from sowing')
    plt.ylabel('mean plant weight')
    plt.title('density=7680')
    plt.legend()
plt.show()
# Out:
# Using matplotlib backend: TkAgg
# Paramètres optimaux : f0 = 0.00376697, KF = 0.06198331, r = 0.67643864
# Coefficient de détermination : R2 = 0.9980
# Paramètres optimaux : f0 = 0.16392076, KF = 0.04684392, r = 0.14451551
# Coefficient de détermination : R2 = 0.9996
# Paramètres optimaux : f0 = 0.00432633, KF = 0.00061799, r = 0.09963598
# Coefficient de détermination : R2 = 0.9996
